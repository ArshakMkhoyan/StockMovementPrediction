# %%
from TechnicalIndicators import get_TI
from DataPreprocessing import *
from Model import LSTM_model
from LoadData import stock_price
from FundamentalIndicators import get_FI_for_model
from matplotlib import pyplot
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Model works good enough with VIX, DXY, but it needs to converge, achives 55.3% with val loss of .6897

# %%
Company = 'XOM'
df = stock_price(Company, "1992-12-31", "2018-12-31")

batch_size = 30 #30, 50
n_days = 5 #5, 7

# df = get_FI_for_model(df)
df = get_TI(df)

(reframed_train_x, reframed_train_y), (reframed_test_x, reframed_test_y) = ready_data(df, split_ratio=0.85, batch_size=batch_size, n_days=n_days)

history, model = LSTM_model(reframed_train_x, reframed_train_y, reframed_test_x, reframed_test_y, n_days, batch_size, epochs=120)
# Out:
# Train X shape: (5515, 5, 9)
# Train Y shape: (5515,)
# Test X shape:(955, 5, 9)
# Test Y shape: (955,)
#
# Proportion of Target variable.
# Test set: 0.499
# Train set: 0.5025
#
# Train on 5515 samples, validate on 955 samples
# Epoch 1/120
# 5515/5515 [==============================] - 3s 574us/step - loss: 0.6941 - acc: 0.5102 - val_loss: 0.6934 - val_acc: 0.5016
# Epoch 2/120
# 5515/5515 [==============================] - 1s 252us/step - loss: 0.6932 - acc: 0.5139 - val_loss: 0.6931 - val_acc: 0.5026
# Epoch 3/120
# 5515/5515 [==============================] - 1s 253us/step - loss: 0.6931 - acc: 0.5166 - val_loss: 0.6929 - val_acc: 0.4974
# Epoch 4/120
# 5515/5515 [==============================] - 1s 249us/step - loss: 0.6927 - acc: 0.5137 - val_loss: 0.6929 - val_acc: 0.5120
# Epoch 5/120
# 5515/5515 [==============================] - 1s 253us/step - loss: 0.6929 - acc: 0.5133 - val_loss: 0.6929 - val_acc: 0.5204
# Epoch 6/120
# ...

# %%
# reframed_test_y[:480].shape

# %%
reframed_test_x.shape

# %%
model.evaluate(reframed_test_x, reframed_test_y)

# %%
pyplot.plot(history.history['loss'][:], label='train')
pyplot.plot(history.history['val_loss'][:], label='test')
pyplot.title('Loss')
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(history.history['acc'][:], label='train')
pyplot.plot(history.history['val_acc'][:], label='test')
pyplot.title('Accuracy')
pyplot.legend()
pyplot.show()

# %%
model.summary()
